# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
n=200

data=pd.DataFrame({
"experince":np.random.randint(0,15,n),
"education_year":np.random.randint(10,20,n),
"age":np.random.randint(22,60,n)
})

data["salary"]=(
    30000 +
    data["experince"]*4000+
    data["education_year"]*2000+
    data["age"]*500+
    np.random.randn(n)
)
data.head()
# Out:
#    experince  education_year  age         salary
# 0         13              16   29  128501.085651
# 1         12              19   55  143501.091223
# 2          3              11   46   87000.068111
# 3          4              18   51  107501.540196
# 4         10              11   34  108999.122770

# %%
print(data.shape)
print(data.info())
print(data.describe())
# Out:
# (200, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   experince       200 non-null    int64
#  1   education_year  200 non-null    int64
#  2   age             200 non-null    int64
# dtypes: int64(3)
# memory usage: 4.8 KB
# None
#         experince  education_year         age
# count  200.000000      200.000000  200.000000
# mean     7.640000       14.335000   40.435000
# std      4.296826        2.874734   10.715404
# min      0.000000       10.000000   22.000000
# 25%      4.000000       12.000000   30.750000
# 50%      8.000000       14.500000   41.500000
# 75%     11.000000       17.000000   49.000000
# max     14.000000       19.000000   59.000000

# %%
corr=data.corr()

plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)),corr.columns,rotation=45)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
features=["experince","education_year","age"]

for col in features:
    plt.figure()
    plt.scatter(data[col],data["salary"])
    plt.xlabel(col)
    plt.ylabel("salary")
    plt.show()

# %%
x=data[["experince","education_year","age"]]
y=data["salary"]

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)

# %%
mode1=LinearRegression()
mode1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
salary=b0+coefficient(b1)*experince+coefficient(b2)*education_year+coefficient(b3)*age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_360/909835132.py in <cell line: 0>()
# ----> 1 salary=b0+coefficient(b1)*experince+coefficient(b2)*education_year+coefficient(b3)*age
#
# NameError: name 'b0' is not defined

# %%
print(mode1.coef_)
print(mode1.intercept_)
# Out:
# [4000.00249519 2000.00104493  499.9968986 ]
# 30000.123083077793

# %%
y_pred=mode1.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(mse,rmse,r2)
# Out:
# 1.1604238133358624 1.0772296938609993 0.9999999953571536

# %%
new_data=pd.DataFrame({
    "experince":[5],
    "education_year":[16],
    "age":[38]
})

print(mode1.predict(new_data))
# Out:
# [101000.03442481]
